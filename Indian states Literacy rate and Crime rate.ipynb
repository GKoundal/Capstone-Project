# %%
table_data = [
    {"State": "Arunachal Pradesh", "Literacy": 66.95, "Crime Rate": 204.5},
    {"State": "Assam", "Literacy": 73.18, "Crime Rate": 328.5},
    {"State": "Bihar", "Literacy": 63.82, "Crime Rate": 181.9},
    {"State": "Gujarat", "Literacy": 79.31, "Crime Rate": 690.3},
    {"State": "Haryana", "Literacy": 76.64, "Crime Rate": 518.3},
    {"State": "Jammu & Kashmir", "Literacy": 68.74, "Crime Rate": 213.7},
    {"State": "Jharkhand", "Literacy": 67.63, "Crime Rate": 141.5},
    {"State": "Karnataka", "Literacy": 75.6, "Crime Rate": 286.8},
    {"State": "Kerala", "Literacy": 93.91, "Crime Rate": 1980.1},
    {"State": "Maharashtra", "Literacy": 82.91, "Crime Rate": 357.4},
    {"State": "Manipur", "Literacy": 79.85, "Crime Rate": 157.6},
    {"State": "Meghalaya", "Literacy": 75.48, "Crime Rate": 128.8},
    {"State": "Mizoram", "Literacy": 91.58, "Crime Rate": 261.7},
    {"State": "Punjab", "Literacy": 76.68, "Crime Rate": 197.7},
    {"State": "Rajasthan", "Literacy": 67.06, "Crime Rate": 342.7},
    {"State": "Sikkim", "Literacy": 82.2, "Crime Rate": 156.9},
    {"State": "Tamil Nadu", "Literacy": 80.33, "Crime Rate": 672.3},
    {"State": "Tripura", "Literacy": 87.75, "Crime Rate": 106.3},
    {"State": "Uttar Pradesh", "Literacy": 69.72, "Crime Rate": 225.3},
    {"State": "Uttarakhand", "Literacy": 79.63, "Crime Rate": 150.5},
    {"State": "West Bengal", "Literacy": 77.08, "Crime Rate": 217.8},
    {"State": "Andhra Pradesh", "Literacy": 67.66, "Crime Rate": 250.1},
    {"State": "Chhattisgarh", "Literacy": 71.04, "Crime Rate": 323.9},
    {"State": "Goa", "Literacy": 87.4, "Crime Rate": 186.2},
    {"State": "Himachal Pradesh", "Literacy": 83.78, "Crime Rate": 242.3},
    {"State": "Madhya Pradesh", "Literacy": 70.63, "Crime Rate": 466.6},
    {"State": "Nagaland", "Literacy": 80.11, "Crime Rate": 79.8},
    {"State": "Odisha", "Literacy": 73.45, "Crime Rate": 243.2}
]

# Print the collected data
for data in table_data:
    print("State:", data["State"])
    print("Literacy Rate:", data["Literacy"])
    print("Crime Rate:", data["Crime Rate"])
    print()
# Out:
# State: Arunachal Pradesh
# Literacy Rate: 66.95
# Crime Rate: 204.5
#
# State: Assam
# Literacy Rate: 73.18
# Crime Rate: 328.5
#
# State: Bihar
# Literacy Rate: 63.82
# Crime Rate: 181.9
#
# State: Gujarat
# Literacy Rate: 79.31
# Crime Rate: 690.3
#
# State: Haryana
# Literacy Rate: 76.64
# Crime Rate: 518.3
#
# State: Jammu & Kashmir
# Literacy Rate: 68.74
# Crime Rate: 213.7
#
# State: Jharkhand
# Literacy Rate: 67.63
# Crime Rate: 141.5
#
# State: Karnataka
# Literacy Rate: 75.6
# Crime Rate: 286.8
#
# State: Kerala
# Literacy Rate: 93.91
# Crime Rate: 1980.1
#
# State: Maharashtra
# Literacy Rate: 82.91
# Crime Rate: 357.4
#
# State: Manipur
# Literacy Rate: 79.85
# Crime Rate: 157.6
#
# State: Meghalaya
# Literacy Rate: 75.48
# Crime Rate: 128.8
#
# State: Mizoram
# Literacy Rate: 91.58
# Crime Rate: 261.7
#
# State: Punjab
# Literacy Rate: 76.68
# Crime Rate: 197.7
#
# State: Rajasthan
# Literacy Rate: 67.06
# Crime Rate: 342.7
#
# State: Sikkim
# Literacy Rate: 82.2
# ...
