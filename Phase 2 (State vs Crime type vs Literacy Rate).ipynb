# %%
table_data = [
    {"State": "Arunachal Pradesh", "Literacy": 66.95, "Crime Type": "Murder"},
    {"State": "Assam", "Literacy": 73.18, "Crime Type": "Murder"},
    {"State": "Bihar", "Literacy": 63.82, "Crime Type": "Theft"},
    {"State": "Gujarat", "Literacy": 79.31, "Crime Type": "Fraud"},
    {"State": "Haryana", "Literacy": 76.64, "Crime Type": "Abduction"},
    {"State": "Jammu & Kashmir", "Literacy": 68.74, "Crime Type": "Abduction"},
    {"State": "Jharkhand", "Literacy": 67.63, "Crime Type": "Murder"},
    {"State": "Karnataka", "Literacy": 75.6, "Crime Type": "Murder"},
    {"State": "Kerala", "Literacy": 93.91, "Crime Type": "Robbery"},
    {"State": "Maharashtra", "Literacy": 82.91, "Crime Type": "Fraud"},
    {"State": "Manipur", "Literacy": 79.85, "Crime Type": "Robbery"},
    {"State": "Meghalaya", "Literacy": 75.48, "Crime Type": "Robbery"},
    {"State": "Mizoram", "Literacy": 91.58, "Crime Type": "Robbery"},
    {"State": "Punjab", "Literacy": 76.68, "Crime Type": "Murder"},
    {"State": "Rajasthan", "Literacy": 67.06, "Crime Type": "Murder"},
    {"State": "Sikkim", "Literacy": 82.2, "Crime Type": "Fraud"},
    {"State": "Tamil Nadu", "Literacy": 80.33, "Crime Type": "Fraud"},
    {"State": "Tripura", "Literacy": 87.75, "Crime Type": "Robbery"},
    {"State": "Uttar Pradesh", "Literacy": 69.72, "Crime Type": "Murder"},
    {"State": "Uttarakhand", "Literacy": 79.63, "Crime Type": "Bribe"},
    {"State": "West Bengal", "Literacy": 77.08, "Crime Type": "Assault"},
    {"State": "Andhra Pradesh", "Literacy": 67.66, "Crime Type": "Robbery"},
    {"State": "Chhattisgarh", "Literacy": 71.04, "Crime Type": "Abduction"},
    {"State": "Goa", "Literacy": 87.4, "Crime Type": "Fraud"},
    {"State": "Himachal Pradesh", "Literacy": 83.78, "Crime Type": "Bribe"},
    {"State": "Madhya Pradesh", "Literacy": 70.63, "Crime Type": "Robbery"},
    {"State": "Nagaland", "Literacy": 80.11, "Crime Type": "Robbery"},
    {"State": "Odisha", "Literacy": 73.45, "Crime Type": "Abduction"}
]


for data in table_data:
    print("State:", data["State"])
    print("Literacy Rate:", data["Literacy"])
    print("Crime Type:", data["Crime Type"])
    print()
# Out:
# State: Arunachal Pradesh
# Literacy Rate: 66.95
# Crime Type: Murder
#
# State: Assam
# Literacy Rate: 73.18
# Crime Type: Murder
#
# State: Bihar
# Literacy Rate: 63.82
# Crime Type: Theft
#
# State: Gujarat
# Literacy Rate: 79.31
# Crime Type: Fraud
#
# State: Haryana
# Literacy Rate: 76.64
# Crime Type: Abduction
#
# State: Jammu & Kashmir
# Literacy Rate: 68.74
# Crime Type: Abduction
#
# State: Jharkhand
# Literacy Rate: 67.63
# Crime Type: Murder
#
# State: Karnataka
# Literacy Rate: 75.6
# Crime Type: Murder
#
# State: Kerala
# Literacy Rate: 93.91
# Crime Type: Robbery
#
# State: Maharashtra
# Literacy Rate: 82.91
# Crime Type: Fraud
#
# State: Manipur
# Literacy Rate: 79.85
# Crime Type: Robbery
#
# State: Meghalaya
# Literacy Rate: 75.48
# Crime Type: Robbery
#
# State: Mizoram
# Literacy Rate: 91.58
# Crime Type: Robbery
#
# State: Punjab
# Literacy Rate: 76.68
# Crime Type: Murder
#
# State: Rajasthan
# Literacy Rate: 67.06
# Crime Type: Murder
#
# State: Sikkim
# ...
