# %%
table_data = [
    {"State": "Arunachal Pradesh", "2021 Crime Rate": 3.62, "2023 Crime Rate": 51.7},
    {"State": "Assam", "2021 Crime Rate": 169.86, "2023 Crime Rate": 328.5},
    {"State": "Bihar", "2021 Crime Rate": 299.56, "2023 Crime Rate": 181.9},
    {"State": "Gujarat", "2021 Crime Rate": 372.87, "2023 Crime Rate": 690.3},
    {"State": "Haryana", "2021 Crime Rate": 466.91, "2023 Crime Rate": 518.3},
    {"State": "Jammu & Kashmir", "2021 Crime Rate": 235.7, "2023 Crime Rate": 213.7},
    {"State": "Jharkhand", "2021 Crime Rate": 157.3, "2023 Crime Rate": 141.5},
    {"State": "Karnataka", "2021 Crime Rate": 244.4, "2023 Crime Rate": 286.8},
    {"State": "Kerala", "2021 Crime Rate": 1477.2, "2023 Crime Rate": 1980.1},
    {"State": "Maharashtra", "2021 Crime Rate": 433.5, "2023 Crime Rate": 357.4},
    {"State": "Manipur", "2021 Crime Rate": 101.0, "2023 Crime Rate": 157.6},
    {"State": "Meghalaya", "2021 Crime Rate": 104.0, "2023 Crime Rate": 128.8},
    {"State": "Mizoram", "2021 Crime Rate": 262.2, "2023 Crime Rate": 261.7},
    {"State": "Punjab", "2021 Crime Rate": 242.0, "2023 Crime Rate": 197.7},
    {"State": "Rajasthan", "2021 Crime Rate": 357.6, "2023 Crime Rate": 342.7},
    {"State": "Sikkim", "2021 Crime Rate": 107.4, "2023 Crime Rate": 156.9},
    {"State": "Tamil Nadu", "2021 Crime Rate": 989.5, "2023 Crime Rate": 672.3},
    {"State": "Tripura", "2021 Crime Rate": 117.3, "2023 Crime Rate": 106.3},
    {"State": "Uttar Pradesh", "2021 Crime Rate": 262.4, "2023 Crime Rate": 225.3},
    {"State": "Uttarakhand", "2021 Crime Rate": 304.9, "2023 Crime Rate": 150.5},
    {"State": "West Bengal", "2021 Crime Rate": 185.0, "2023 Crime Rate": 217.8},
    {"State": "Andhra Pradesh", "2021 Crime Rate": 420.4, "2023 Crime Rate": 250.1},
    {"State": "Chhattisgarh", "2021 Crime Rate": 373.7, "2023 Crime Rate": 323.9},
    {"State": "Goa", "2021 Crime Rate": 191.6, "2023 Crime Rate": 186.2},
    {"State": "Himachal Pradesh", "2021 Crime Rate": 254.3, "2023 Crime Rate": 242.3},
    {"State": "Madhya Pradesh", "2021 Crime Rate": 560.8, "2023 Crime Rate": 466.6},
    {"State": "Nagaland", "2021 Crime Rate": 67.2, "2023 Crime Rate": 79.8},
    {"State": "Odisha", "2021 Crime Rate": 339.4, "2023 Crime Rate": 243.2}
]


for data in table_data:
    print("State:", data["State"])
    print("2021 Crime Rate:", data["2021 Crime Rate"])
    print("2023 Crime Rate:", data["2023 Crime Rate"])
    print()
# Out:
# State: Arunachal Pradesh
# 2021 Crime Rate: 3.62
# 2023 Crime Rate: 51.7
#
# State: Assam
# 2021 Crime Rate: 169.86
# 2023 Crime Rate: 328.5
#
# State: Bihar
# 2021 Crime Rate: 299.56
# 2023 Crime Rate: 181.9
#
# State: Gujarat
# 2021 Crime Rate: 372.87
# 2023 Crime Rate: 690.3
#
# State: Haryana
# 2021 Crime Rate: 466.91
# 2023 Crime Rate: 518.3
#
# State: Jammu & Kashmir
# 2021 Crime Rate: 235.7
# 2023 Crime Rate: 213.7
#
# State: Jharkhand
# 2021 Crime Rate: 157.3
# 2023 Crime Rate: 141.5
#
# State: Karnataka
# 2021 Crime Rate: 244.4
# 2023 Crime Rate: 286.8
#
# State: Kerala
# 2021 Crime Rate: 1477.2
# 2023 Crime Rate: 1980.1
#
# State: Maharashtra
# 2021 Crime Rate: 433.5
# 2023 Crime Rate: 357.4
#
# State: Manipur
# 2021 Crime Rate: 101.0
# 2023 Crime Rate: 157.6
#
# State: Meghalaya
# 2021 Crime Rate: 104.0
# 2023 Crime Rate: 128.8
#
# State: Mizoram
# 2021 Crime Rate: 262.2
# 2023 Crime Rate: 261.7
#
# State: Punjab
# 2021 Crime Rate: 242.0
# 2023 Crime Rate: 197.7
#
# ...
