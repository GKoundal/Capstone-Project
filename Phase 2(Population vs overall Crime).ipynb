# %%
table_data = [
    {"State": "Arunachal Pradesh", "Population": 1562000, "Crime Rate": 204.5},
    {"State": "Assam", "Population": 35713000, "Crime Rate": 328.5},
    {"State": "Bihar", "Population": 126756000, "Crime Rate": 181.9},
    {"State": "Gujarat", "Population": 71507000, "Crime Rate": 690.3},
    {"State": "Haryana", "Population": 30209000, "Crime Rate": 518.3},
    {"State": "Jammu & Kashmir", "Population": 13603000, "Crime Rate": 213.7},
    {"State": "Jharkhand", "Population": 39466000, "Crime Rate": 141.5},
    {"State": "Karnataka", "Population": 6769200, "Crime Rate": 286.8},
    {"State": "Kerala", "Population": 35776000, "Crime Rate": 1980.1},
    {"State": "Maharashtra", "Population": 126385000, "Crime Rate": 357.4},
    {"State": "Manipur", "Population": 3223000, "Crime Rate": 157.6},
    {"State": "Meghalaya", "Population": 3349000, "Crime Rate": 128.8},
    {"State": "Mizoram", "Population": 1238000, "Crime Rate": 261.7},
    {"State": "Punjab", "Population": 30730000, "Crime Rate": 197.7},
    {"State": "Rajasthan", "Population": 81025000, "Crime Rate": 342.7},
    {"State": "Sikkim", "Population": 689000, "Crime Rate": 156.9},
    {"State": "Tamil Nadu", "Population": 76860000, "Crime Rate": 672.3},
    {"State": "Tripura", "Population": 4147000, "Crime Rate": 106.3},
    {"State": "Uttar Pradesh", "Population": 235687000, "Crime Rate": 225.3},
    {"State": "Uttarakhand", "Population": 11637000, "Crime Rate": 150.5},
    {"State": "West Bengal", "Population": 99084000, "Crime Rate": 217.8},
    {"State": "Andhra Pradesh", "Population": 53156000, "Crime Rate": 250.1},
    {"State": "Chhattisgarh", "Population": 30180000, "Crime Rate": 323.9},
    {"State": "Goa", "Population": 1575000, "Crime Rate": 186.2},
    {"State": "Himachal Pradesh", "Population": 7468000, "Crime Rate": 242.3},
    {"State": "Madhya Pradesh", "Population": 86579000, "Crime Rate": 466.6},
    {"State": "Nagaland", "Population": 2233000, "Crime Rate": 79.8},
    {"State": "Odisha", "Population": 46276000, "Crime Rate": 243.2}
]


for data in table_data:
    print("State:", data["State"])
    print("Population:", data["Population"])
    print("Crime Rate:", data["Crime Rate"])
    print()
# Out:
# State: Arunachal Pradesh
# Population: 1562000
# Crime Rate: 204.5
#
# State: Assam
# Population: 35713000
# Crime Rate: 328.5
#
# State: Bihar
# Population: 126756000
# Crime Rate: 181.9
#
# State: Gujarat
# Population: 71507000
# Crime Rate: 690.3
#
# State: Haryana
# Population: 30209000
# Crime Rate: 518.3
#
# State: Jammu & Kashmir
# Population: 13603000
# Crime Rate: 213.7
#
# State: Jharkhand
# Population: 39466000
# Crime Rate: 141.5
#
# State: Karnataka
# Population: 6769200
# Crime Rate: 286.8
#
# State: Kerala
# Population: 35776000
# Crime Rate: 1980.1
#
# State: Maharashtra
# Population: 126385000
# Crime Rate: 357.4
#
# State: Manipur
# Population: 3223000
# Crime Rate: 157.6
#
# State: Meghalaya
# Population: 3349000
# Crime Rate: 128.8
#
# State: Mizoram
# Population: 1238000
# Crime Rate: 261.7
#
# State: Punjab
# Population: 30730000
# Crime Rate: 197.7
#
# State: Rajasthan
# Population: 81025000
# Crime Rate: 342.7
#
# State: Sikkim
# Population: 689000
# ...
